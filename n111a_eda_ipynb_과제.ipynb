# %% [markdown]
# <a href="https://colab.research.google.com/github/fkvldjtm/LGMRepo/blob/master/n111a_eda_ipynb_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 1*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# ## 1.데이터셋 불러오기 연습
#
# 다음 url에서 엑셀 파일을 불러오세요. (pandas excel)
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx>
#
#   - 데이터셋 변수의 이름은 `df1`, `df2`로 저장하세요.
#   - row가 아닌 column에 '매출액', '영업이익' 이 가도록 데이터를 transpose 하세요.
#   - 이후 아래 링크를 참조하여 첫번째 row를 column name으로 설정하세요.
#
# <https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row>
#
# - 파일은 2개의 시트로 구성되어 있으며 각각 이름은 `008770`, `035250` 입니다.

# %%
import pandas as pd

url = "https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx"

df1 = pd.read_excel(url, sheet_name="008770 ")  # 첫 번째 시트 불러오기
df2 = pd.read_excel(url, sheet_name="035250")  # 두 번째 시트 불러오기

df1 = df1.transpose() # 첫 번째 시트 Matrix Transpose
df2 = df2.transpose() # 두 번째 시트 Matrix Transpose

new_header = df1.iloc[0] # 첫 번재 행 저장
df1 = df1[1:]            # 첫 번째 행 제거
df1.columns = new_header # 데이터 Header(열 이름)에 첫 번째 행 저장

new_header = df2.iloc[0] # 첫 번재 행 저장
df2 = df2[1:]            # 첫 번째 행 제거
df2.columns = new_header # 데이터 Header(열 이름)에 첫 번째 행 저장

# %%
df1
# Out:
# 주요재무정보                  매출액 영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)     14753  574        574  ...        0     NaN         0
# 2019/12\n(IFRS연결)     15440  776        776  ...      350     NaN     34.94
# 2020/03\n(IFRS연결)      9437 -668       -668  ...      NaN     NaN         0
# 2020/06\n(IFRS연결)      5230 -634       -634  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)      8795 -198       -198  ...      NaN     NaN       NaN
# 2020/12(E)\n(IFRS연결)   9980   50        NaN  ...      NaN     NaN       NaN
# 2021/03(E)\n(IFRS연결)   9761  144        NaN  ...      NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)   9820  265        NaN  ...      NaN     NaN       NaN
#
# [8 rows x 32 columns]

# %%
df2
# Out:
# 주요재무정보                 매출액  영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)     4055  1392       1392  ...        0     NaN         0
# 2019/12\n(IFRS연결)     3728   641        641  ...      900     NaN    346.75
# 2020/03\n(IFRS연결)     2360 -1868      -1868  ...      NaN     NaN       NaN
# 2020/06\n(IFRS연결)      346 -1038      -1038  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)      766  -649       -649  ...      NaN     NaN       NaN
# 2020/12(E)\n(IFRS연결)  1581  -434        NaN  ...      NaN     NaN       NaN
# 2021/03(E)\n(IFRS연결)  1473  -187        NaN  ...      NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)  1746   -65        NaN  ...      NaN     NaN       NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# ## 2. 데이터 확인
#
# - 데이터의 dimension을 확인하세요.
# - 데이터의 결측치가 어디에 있는지 확인 후 0으로 대체하세요.
# - 각 데이터 별로 **FCF**의 값을 barplot으로 시각화하세요.
#   - 0보다 큰 값인 셀 개수의 총합을 `num1`에, 작은 값인 셀 개수의 총합을 `num2`에 저장하세요

# %%
import numpy as np
import matplotlib.pyplot as plt

num1 = 0
num2 = 0
print("df1 demension: ",np.shape(df1))  # df1 dimension 확인
print("df2 demension: ",np.shape(df2))  # df2 dimension 확인
# Out:
# df1 demension:  (8, 32)
# df2 demension:  (8, 32)

# %%
#df1.notna()    # df1 결측치 확인
#df2.notna()    # df2 결측치 확인

df1 = df1.fillna(0)  #df1의 결측치를 0으로 채움
df2 = df2.fillna(0)  #df2의 결측치를 0으로 채움

# %%
df1
# Out:
# 주요재무정보                    매출액   영업이익  영업이익(발표기준)  ...  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)     14753.0  574.0       574.0  ...       0.0        0       0.00
# 2019/12\n(IFRS연결)     15440.0  776.0       776.0  ...     350.0        0      34.94
# 2020/03\n(IFRS연결)      9437.0 -668.0      -668.0  ...       0.0        0       0.00
# 2020/06\n(IFRS연결)      5230.0 -634.0      -634.0  ...       0.0        0       0.00
# 2020/09\n(IFRS연결)      8795.0 -198.0      -198.0  ...       0.0        0       0.00
# 2020/12(E)\n(IFRS연결)   9980.0   50.0         0.0  ...       0.0        0       0.00
# 2021/03(E)\n(IFRS연결)   9761.0  144.0         0.0  ...       0.0        0       0.00
# 2021/06(E)\n(IFRS연결)   9820.0  265.0         0.0  ...       0.0        0       0.00
#
# [8 rows x 32 columns]

# %%
df2
# Out:
# 주요재무정보                   매출액    영업이익  영업이익(발표기준)  ...  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)     4055.0  1392.0      1392.0  ...       0.0        0       0.00
# 2019/12\n(IFRS연결)     3728.0   641.0       641.0  ...     900.0        0     346.75
# 2020/03\n(IFRS연결)     2360.0 -1868.0     -1868.0  ...       0.0        0       0.00
# 2020/06\n(IFRS연결)      346.0 -1038.0     -1038.0  ...       0.0        0       0.00
# 2020/09\n(IFRS연결)      766.0  -649.0      -649.0  ...       0.0        0       0.00
# 2020/12(E)\n(IFRS연결)  1581.0  -434.0         0.0  ...       0.0        0       0.00
# 2021/03(E)\n(IFRS연결)  1473.0  -187.0         0.0  ...       0.0        0       0.00
# 2021/06(E)\n(IFRS연결)  1746.0   -65.0         0.0  ...       0.0        0       0.00
#
# [8 rows x 32 columns]

# %%
plt.rc('font', family='NanumBarunGothic') 

plt.subplots_adjust(left=0.125, bottom=0.1,  right=2, top=0.9, wspace=0.2, hspace=0.35) # 그래프 간격 조절
plt.subplot(1,2,1)                            #subplot 생성
plt.axhline(y=0, color='blue', linewidth=1)   #기준선 생성
plt.bar(df1.index,df1['FCF'],color='red');    #그래프 생성

plt.subplot(1,2,2)
plt.axhline(y=0, color='blue', linewidth=1)
plt.bar(df2.index,df2['FCF'],color='green');
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
num1 = sum((df1[['FCF']]>0).sum()) + sum((df2[['FCF']]>0).sum())  # 0보다 큰 값을 가진 셀의 수
num2 = sum((df1[['FCF']]<0).sum()) + sum((df2[['FCF']]<0).sum())  # 0보다 작은 값을 가진 셀의 수
print(num1, num2)
# Out:
# 4 6
# 주요재무정보                   FCF
# 2019/09\n(IFRS연결)     1493.0
# 2019/12\n(IFRS연결)     -589.0
# 2020/03\n(IFRS연결)    -4680.0
# 2020/06\n(IFRS연결)      789.0
# 2020/09\n(IFRS연결)     2975.0
# 2020/12(E)\n(IFRS연결)     0.0
# 2021/03(E)\n(IFRS연결)     0.0
# 2021/06(E)\n(IFRS연결)     0.0

# %% [markdown]
# ## 3. File export
#
# - 읽었던 엑셀 파일의 내용을 2개의 csv로 각각 출력하세요. (python export csv)
#
#   - 이름은 각각 `df1.csv`, `df2.csv` 입니다.

# %%
df1.to_csv('df1.csv',sep=',',na_rep='0')
df2.to_csv('df2.csv',sep=',',na_rep='0')

# %% [markdown]
# ## 4. Error Handling
#
# - 다음의 에러를 고치세요. 결과값은 6912가 나와야합니다.

# %%
a = '1234'
b = 5678

int(a)+b  # type casting
# Out:
# 6912

# %% [markdown]
# ## 5. EDA
#
# 아래의 코드는 palmer penguin 데이터를 불러올 수 있는 코드입니다.
#
# ```python
# import seaborn as sns
#
# pp = sns.load_dataset('penguins')
# ```
#
# 이를 참조하여, `pp`의 `species`와 `sex`변수에 대해서 cross-tabulation을 시행하고, 6개의 값들 중 가장 큰 값을 `num3`에, 가장 작은 값을 `num4`에 저장하세요.

# %%
import seaborn as sns
 
pp = sns.load_dataset('penguins')

pd.crosstab(pp['species'],pp['sex'])  #cross-tabulation
# Out:
# sex        Female  Male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %%
ct_pp = pd.crosstab(pp['species'],pp['sex'])
num3 = (ct_pp.max()).max()
num4 = (ct_pp.min()).min()

print("Max: ",num3)
print("Min: ",num4)
# Out:
# Max:  73
# Min:  34

# %% [markdown]
# ## 🔥 도전과제

# %% [markdown]
# ### penguins 데이터를 계속 사용합니다.
#
# 이에 대해 아래의 task들을 시행하세요.
#
# - 결측치 처리 (제거)
#
# - bill_length_mm에 대해서 qqplot 그리기
#
# - island에 대해서 다른 4개의 numerical feature 를 boxplot으로 표현하기
#
# - 각 numerical feature에 대해서 summary statistics : mean, sd, Quantiles(1Q, 2Q, 3Q, 4Q)를 계산하세요.

# %%
pp = pp.dropna() # 결측치 제거

plt.subplots_adjust(left=0.125, bottom=0.1,  right=4, top=0.9, wspace=0.2, hspace=0.35)
plt.subplot(1,5,1)
stats.probplot(pp['bill_length_mm'],plot=plt) #bill_length_mm에 대해서 qqplot 그리기
plt.subplot(1,5,2)
sns.boxplot(x=pp["island"],y=pp["bill_length_mm"]) #island - bill_length_mm Boxplot
plt.subplot(1,5,3)
sns.boxplot(x=pp["island"],y=pp["bill_depth_mm"]) #island - bill_depth_mm Boxplot
plt.subplot(1,5,4)
sns.boxplot(x=pp["island"],y=pp["flipper_length_mm"]) #island - flipper_length_mm Boxplot
plt.subplot(1,5,5)
sns.boxplot(x=pp["island"],y=pp["body_mass_g"]) #island - body_mass_g Boxplot

# %%
# mean
pp.mean()
# Out:
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# dtype: float64

# %%
#sd
pp.std()
# Out:
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# dtype: float64

# %%
#Quantiles(1Q,2Q,3Q,4Q)
Q1 = pp.quantile(.25)
Q2 = pp.quantile(.5)
Q3 = pp.quantile(.75)
Q4 = pp.quantile(.1)
IQR = Q3-Q1

print("[Q1 25%]\n",Q1)
print("\n[Q2 50%]\n",Q2)
print("\n[Q3 75%]\n",Q3)
print("\n[Q4 100%]\n",Q4)
# Out:
# [Q1 25%]
#  bill_length_mm         39.5
# bill_depth_mm          15.6
# flipper_length_mm     190.0
# body_mass_g          3550.0
# Name: 0.25, dtype: float64
#
# [Q2 50%]
#  bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# Name: 0.5, dtype: float64
#
# [Q3 75%]
#  bill_length_mm         48.6
# bill_depth_mm          18.7
# flipper_length_mm     213.0
# body_mass_g          4775.0
# Name: 0.75, dtype: float64
#
# [Q4 100%]
#  bill_length_mm         36.60
# bill_depth_mm          14.32
# flipper_length_mm     185.00
# body_mass_g          3300.00
# Name: 0.1, dtype: float64
